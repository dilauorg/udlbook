# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-yn4azyld
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-yn4azyld
#   Resolved https://github.com/greydanus/mnist1d to commit fd50cfdf874fab4afc3fae6bdbfa2c6fb2184ee1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post3) (2.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post3) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post3) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post3) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post3) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post3) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post3) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post3) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post3) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post3-py3-none-any.whl size=14371 sha256=e7d080b08e5714aea629f14ba81ba6d4825446a451b4fb869ca324650f47a106
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w3dj5ahh/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post3

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.261503, train error 88.97,  test loss 2.244077, test error 89.10
# Epoch   100, train loss 1.916108, train error 72.10,  test loss 1.778117, test error 70.93
# Epoch   200, train loss 1.899403, train error 71.75,  test loss 1.744939, test error 70.43
# Epoch   300, train loss 1.897884, train error 71.93,  test loss 1.728361, test error 69.47
# Epoch   400, train loss 1.892277, train error 70.57,  test loss 1.731587, test error 69.85
# Epoch   500, train loss 1.889922, train error 71.40,  test loss 1.733494, test error 68.57
# Epoch   600, train loss 1.894399, train error 71.62,  test loss 1.725670, test error 68.95
# Epoch   700, train loss 1.897122, train error 70.95,  test loss 1.746421, test error 69.00
# Epoch   800, train loss 1.889966, train error 70.82,  test loss 1.711453, test error 69.30
# Epoch   900, train loss 1.889919, train error 71.22,  test loss 1.714974, test error 69.47
# Training model with   4 hidden variables
# Epoch     0, train loss 2.206027, train error 84.10,  test loss 2.176161, test error 81.93
# Epoch   100, train loss 1.824229, train error 67.25,  test loss 1.717551, test error 65.80
# Epoch   200, train loss 1.759106, train error 63.08,  test loss 1.625629, test error 61.33
# Epoch   300, train loss 1.736498, train error 61.83,  test loss 1.604917, test error 60.67
# Epoch   400, train loss 1.733371, train error 61.65,  test loss 1.593461, test error 60.22
# Epoch   500, train loss 1.728933, train error 61.33,  test loss 1.598420, test error 60.42
# Epoch   600, train loss 1.727173, train error 61.33,  test loss 1.600524, test error 60.72
# Epoch   700, train loss 1.728359, train error 61.20,  test loss 1.598205, test error 60.95
# Epoch   800, train loss 1.727370, train error 61.92,  test loss 1.598449, test error 60.58
# Epoch   900, train loss 1.728881, train error 62.55,  test loss 1.602789, test error 61.25
# Training model with   6 hidden variables
# Epoch     0, train loss 2.305110, train error 88.93,  test loss 2.301563, test error 88.85
# Epoch   100, train loss 1.687892, train error 61.08,  test loss 1.495018, test error 57.38
# Epoch   200, train loss 1.643234, train error 58.50,  test loss 1.474475, test error 56.35
# Epoch   300, train loss 1.627348, train error 58.53,  test loss 1.459419, test error 55.35
# Epoch   400, train loss 1.625087, train error 58.08,  test loss 1.465737, test error 56.72
# Epoch   500, train loss 1.614091, train error 57.65,  test loss 1.457158, test error 55.15
# Epoch   600, train loss 1.609696, train error 57.50,  test loss 1.460363, test error 55.80
# Epoch   700, train loss 1.607936, train error 57.25,  test loss 1.461800, test error 55.60
# Epoch   800, train loss 1.610984, train error 57.97,  test loss 1.473771, test error 56.70
# Epoch   900, train loss 1.605679, train error 57.85,  test loss 1.474249, test error 55.92
# Training model with   8 hidden variables
# Epoch     0, train loss 2.240458, train error 83.22,  test loss 2.227564, test error 83.62
# Epoch   100, train loss 1.571982, train error 54.10,  test loss 1.398525, test error 51.80
# Epoch   200, train loss 1.521385, train error 52.12,  test loss 1.371472, test error 51.08
# Epoch   300, train loss 1.508155, train error 51.88,  test loss 1.369386, test error 50.97
# Epoch   400, train loss 1.495507, train error 52.08,  test loss 1.345881, test error 50.33
# Epoch   500, train loss 1.491798, train error 52.00,  test loss 1.359819, test error 50.42
# Epoch   600, train loss 1.482554, train error 51.28,  test loss 1.348639, test error 50.38
# Epoch   700, train loss 1.478083, train error 51.45,  test loss 1.351047, test error 50.88
# Epoch   800, train loss 1.475713, train error 51.28,  test loss 1.356390, test error 50.55
# Epoch   900, train loss 1.480804, train error 51.92,  test loss 1.359340, test error 50.45
# Training model with  10 hidden variables
# Epoch     0, train loss 2.280790, train error 86.20,  test loss 2.288470, test error 86.90
# Epoch   100, train loss 1.453111, train error 48.40,  test loss 1.271121, test error 46.50
# Epoch   200, train loss 1.418187, train error 47.78,  test loss 1.272474, test error 47.70
# Epoch   300, train loss 1.403575, train error 46.62,  test loss 1.276762, test error 47.67
# Epoch   400, train loss 1.386058, train error 45.53,  test loss 1.277823, test error 47.47
# Epoch   500, train loss 1.376549, train error 45.03,  test loss 1.283293, test error 47.83
# Epoch   600, train loss 1.368376, train error 45.10,  test loss 1.297891, test error 47.53
# Epoch   700, train loss 1.363702, train error 45.03,  test loss 1.304376, test error 47.50
# Epoch   800, train loss 1.359411, train error 44.62,  test loss 1.316233, test error 47.15
# Epoch   900, train loss 1.359175, train error 44.92,  test loss 1.323313, test error 47.65
# Training model with  14 hidden variables
# Epoch     0, train loss 2.243720, train error 83.50,  test loss 2.227031, test error 82.90
# Epoch   100, train loss 1.396486, train error 46.22,  test loss 1.232527, test error 46.22
# Epoch   200, train loss 1.326177, train error 44.28,  test loss 1.221819, test error 45.90
# Epoch   300, train loss 1.296613, train error 43.80,  test loss 1.227744, test error 45.60
# Epoch   400, train loss 1.274961, train error 42.97,  test loss 1.238893, test error 46.75
# Epoch   500, train loss 1.262081, train error 43.05,  test loss 1.271612, test error 46.50
# Epoch   600, train loss 1.255022, train error 41.78,  test loss 1.285880, test error 47.67
# Epoch   700, train loss 1.247056, train error 41.70,  test loss 1.282663, test error 47.38
# Epoch   800, train loss 1.241920, train error 41.25,  test loss 1.293547, test error 47.17
# Epoch   900, train loss 1.239581, train error 41.22,  test loss 1.304806, test error 47.30
# Training model with  18 hidden variables
# Epoch     0, train loss 2.204258, train error 82.53,  test loss 2.209444, test error 82.18
# Epoch   100, train loss 1.353831, train error 45.45,  test loss 1.326837, test error 49.90
# Epoch   200, train loss 1.245617, train error 42.28,  test loss 1.361615, test error 49.95
# Epoch   300, train loss 1.210094, train error 40.00,  test loss 1.443723, test error 51.85
# Epoch   400, train loss 1.185477, train error 39.85,  test loss 1.454670, test error 51.17
# Epoch   500, train loss 1.166871, train error 39.45,  test loss 1.499115, test error 52.25
# Epoch   600, train loss 1.161245, train error 39.90,  test loss 1.521912, test error 51.53
# Epoch   700, train loss 1.152631, train error 39.83,  test loss 1.534311, test error 51.90
# Epoch   800, train loss 1.141662, train error 39.08,  test loss 1.573269, test error 52.40
# Epoch   900, train loss 1.148485, train error 39.25,  test loss 1.573411, test error 52.30
# Training model with  22 hidden variables
# Epoch     0, train loss 2.218472, train error 83.62,  test loss 2.190101, test error 82.53
# Epoch   100, train loss 1.286926, train error 42.88,  test loss 1.349052, test error 50.65
# Epoch   200, train loss 1.178596, train error 38.95,  test loss 1.390024, test error 50.78
# Epoch   300, train loss 1.114325, train error 36.80,  test loss 1.461566, test error 51.42
# Epoch   400, train loss 1.088994, train error 37.05,  test loss 1.528666, test error 51.88
# Epoch   500, train loss 1.066673, train error 36.10,  test loss 1.612732, test error 52.90
# Epoch   600, train loss 1.035293, train error 35.35,  test loss 1.625141, test error 52.85
# Epoch   700, train loss 1.030530, train error 35.22,  test loss 1.697070, test error 54.00
# Epoch   800, train loss 1.016518, train error 34.78,  test loss 1.752049, test error 54.28
# Epoch   900, train loss 1.016734, train error 34.72,  test loss 1.785427, test error 54.00
# Training model with  26 hidden variables
# Epoch     0, train loss 2.140702, train error 77.97,  test loss 2.118725, test error 78.85
# Epoch   100, train loss 1.199176, train error 39.83,  test loss 1.345544, test error 49.83
# Epoch   200, train loss 1.053248, train error 34.97,  test loss 1.451667, test error 50.22
# Epoch   300, train loss 0.973737, train error 32.95,  test loss 1.561094, test error 52.35
# Epoch   400, train loss 0.920774, train error 30.53,  test loss 1.661217, test error 52.62
# Epoch   500, train loss 0.883014, train error 29.88,  test loss 1.805783, test error 53.58
# Epoch   600, train loss 0.861676, train error 29.47,  test loss 1.930193, test error 54.08
# Epoch   700, train loss 0.831527, train error 27.88,  test loss 1.986668, test error 55.12
# Epoch   800, train loss 0.838862, train error 28.47,  test loss 2.042416, test error 54.38
# Epoch   900, train loss 0.821809, train error 27.90,  test loss 2.128383, test error 55.10
# Training model with  30 hidden variables
# Epoch     0, train loss 2.154236, train error 79.18,  test loss 2.109050, test error 77.72
# Epoch   100, train loss 1.089937, train error 35.78,  test loss 1.341468, test error 48.75
# Epoch   200, train loss 0.922676, train error 29.45,  test loss 1.577975, test error 50.38
# Epoch   300, train loss 0.836841, train error 27.57,  test loss 1.754486, test error 51.60
# Epoch   400, train loss 0.771819, train error 25.85,  test loss 1.900641, test error 51.62
# Epoch   500, train loss 0.739694, train error 25.28,  test loss 2.035443, test error 52.20
# Epoch   600, train loss 0.726333, train error 24.00,  test loss 2.228894, test error 54.03
# Epoch   700, train loss 0.703364, train error 23.97,  test loss 2.283331, test error 53.60
# Epoch   800, train loss 0.699157, train error 24.07,  test loss 2.370544, test error 54.25
# Epoch   900, train loss 0.703223, train error 23.95,  test loss 2.380813, test error 54.67
# Training model with  35 hidden variables
# Epoch     0, train loss 2.180954, train error 78.85,  test loss 2.156871, test error 78.82
# Epoch   100, train loss 0.967383, train error 31.78,  test loss 1.368106, test error 48.90
# Epoch   200, train loss 0.764235, train error 24.40,  test loss 1.624175, test error 49.92
# Epoch   300, train loss 0.678570, train error 22.43,  test loss 1.896579, test error 50.78
# Epoch   400, train loss 0.603800, train error 20.50,  test loss 2.189460, test error 51.78
# Epoch   500, train loss 0.540732, train error 17.12,  test loss 2.474015, test error 52.53
# Epoch   600, train loss 0.522771, train error 17.03,  test loss 2.818032, test error 53.88
# Epoch   700, train loss 0.518282, train error 17.78,  test loss 3.100594, test error 53.60
# Epoch   800, train loss 0.504074, train error 16.90,  test loss 3.385853, test error 54.25
# Epoch   900, train loss 0.443877, train error 15.00,  test loss 3.566355, test error 54.65
# Training model with  40 hidden variables
# Epoch     0, train loss 2.151050, train error 78.85,  test loss 2.142398, test error 78.57
# Epoch   100, train loss 0.944140, train error 30.50,  test loss 1.488903, test error 53.08
# Epoch   200, train loss 0.655242, train error 21.38,  test loss 1.968418, test error 53.70
# Epoch   300, train loss 0.523200, train error 16.93,  test loss 2.635102, test error 54.83
# Epoch   400, train loss 0.396197, train error 12.72,  test loss 3.339385, test error 56.90
# Epoch   500, train loss 0.360399, train error 12.75,  test loss 4.120525, test error 58.17
# Epoch   600, train loss 0.294503, train error 9.97,  test loss 4.922235, test error 58.95
# Epoch   700, train loss 0.253491, train error 8.68,  test loss 5.685927, test error 58.95
# Epoch   800, train loss 0.231291, train error 7.80,  test loss 6.353079, test error 58.65
# Epoch   900, train loss 0.287600, train error 10.20,  test loss 6.980751, test error 58.70
# Training model with  45 hidden variables
# Epoch     0, train loss 2.092466, train error 77.22,  test loss 2.059640, test error 77.90
# Epoch   100, train loss 0.813603, train error 25.95,  test loss 1.450546, test error 47.62
# Epoch   200, train loss 0.449782, train error 13.03,  test loss 2.283052, test error 51.67
# Epoch   300, train loss 0.265629, train error 7.85,  test loss 3.554978, test error 55.20
# Epoch   400, train loss 0.154159, train error 3.97,  test loss 5.010817, test error 56.00
# Epoch   500, train loss 0.195778, train error 6.75,  test loss 6.462640, test error 57.22
# Epoch   600, train loss 0.248248, train error 8.50,  test loss 7.729859, test error 57.05
# Epoch   700, train loss 0.009445, train error 0.00,  test loss 8.402332, test error 56.30
# Epoch   800, train loss 0.006438, train error 0.00,  test loss 9.000175, test error 56.20
# Epoch   900, train loss 0.004939, train error 0.00,  test loss 9.445279, test error 56.15
# Training model with  50 hidden variables
# Epoch     0, train loss 2.075655, train error 77.95,  test loss 2.029309, test error 77.07
# Epoch   100, train loss 0.692136, train error 21.15,  test loss 1.519579, test error 48.50
# Epoch   200, train loss 0.346060, train error 10.95,  test loss 2.579016, test error 51.80
# Epoch   300, train loss 0.131444, train error 2.22,  test loss 4.096125, test error 55.03
# Epoch   400, train loss 0.033579, train error 0.05,  test loss 5.618889, test error 55.55
# Epoch   500, train loss 0.014972, train error 0.00,  test loss 6.600669, test error 55.85
# Epoch   600, train loss 0.009246, train error 0.00,  test loss 7.213384, test error 55.58
# Epoch   700, train loss 0.006576, train error 0.00,  test loss 7.684505, test error 55.85
# Epoch   800, train loss 0.005073, train error 0.00,  test loss 8.063362, test error 55.92
# Epoch   900, train loss 0.004057, train error 0.00,  test loss 8.375734, test error 55.92
# Training model with  55 hidden variables
# Epoch     0, train loss 2.058288, train error 77.03,  test loss 2.000254, test error 76.43
# Epoch   100, train loss 0.635669, train error 20.10,  test loss 1.736549, test error 52.55
# Epoch   200, train loss 0.233672, train error 6.60,  test loss 3.158098, test error 55.33
# Epoch   300, train loss 0.039611, train error 0.05,  test loss 4.899775, test error 55.90
# Epoch   400, train loss 0.014494, train error 0.00,  test loss 5.952736, test error 55.72
# Epoch   500, train loss 0.008446, train error 0.00,  test loss 6.591031, test error 55.88
# Epoch   600, train loss 0.005736, train error 0.00,  test loss 7.045553, test error 56.00
# Epoch   700, train loss 0.004296, train error 0.00,  test loss 7.396097, test error 55.95
# Epoch   800, train loss 0.003400, train error 0.00,  test loss 7.688684, test error 55.78
# Epoch   900, train loss 0.002778, train error 0.00,  test loss 7.928385, test error 55.67
# Training model with  60 hidden variables
# Epoch     0, train loss 2.045694, train error 76.03,  test loss 2.001151, test error 77.00
# Epoch   100, train loss 0.536367, train error 16.45,  test loss 1.828152, test error 53.12
# Epoch   200, train loss 0.101071, train error 1.30,  test loss 3.565743, test error 54.25
# Epoch   300, train loss 0.018746, train error 0.00,  test loss 4.918385, test error 54.97
# Epoch   400, train loss 0.009142, train error 0.00,  test loss 5.598575, test error 55.12
# Epoch   500, train loss 0.005914, train error 0.00,  test loss 6.057086, test error 55.38
# Epoch   600, train loss 0.004222, train error 0.00,  test loss 6.397420, test error 55.42
# Epoch   700, train loss 0.003269, train error 0.00,  test loss 6.670002, test error 55.45
# Epoch   800, train loss 0.002623, train error 0.00,  test loss 6.897339, test error 55.38
# Epoch   900, train loss 0.002185, train error 0.00,  test loss 7.089032, test error 55.33
# Training model with  70 hidden variables
# Epoch     0, train loss 2.063849, train error 76.10,  test loss 2.017418, test error 76.68
# Epoch   100, train loss 0.329260, train error 7.20,  test loss 1.977601, test error 51.40
# Epoch   200, train loss 0.030219, train error 0.00,  test loss 3.621758, test error 54.15
# Epoch   300, train loss 0.010685, train error 0.00,  test loss 4.377238, test error 54.12
# Epoch   400, train loss 0.006035, train error 0.00,  test loss 4.809777, test error 54.10
# Epoch   500, train loss 0.004061, train error 0.00,  test loss 5.112526, test error 54.45
# Epoch   600, train loss 0.003034, train error 0.00,  test loss 5.344580, test error 54.25
# Epoch   700, train loss 0.002375, train error 0.00,  test loss 5.532576, test error 54.38
# Epoch   800, train loss 0.001943, train error 0.00,  test loss 5.687346, test error 54.25
# Epoch   900, train loss 0.001633, train error 0.00,  test loss 5.824239, test error 54.25
# Training model with  80 hidden variables
# Epoch     0, train loss 2.028692, train error 75.05,  test loss 1.967575, test error 75.43
# Epoch   100, train loss 0.242426, train error 4.45,  test loss 2.008466, test error 51.55
# Epoch   200, train loss 0.020555, train error 0.00,  test loss 3.429394, test error 52.75
# Epoch   300, train loss 0.008085, train error 0.00,  test loss 4.014599, test error 53.00
# Epoch   400, train loss 0.004809, train error 0.00,  test loss 4.360180, test error 53.03
# Epoch   500, train loss 0.003314, train error 0.00,  test loss 4.604338, test error 52.90
# Epoch   600, train loss 0.002490, train error 0.00,  test loss 4.792571, test error 52.90
# Epoch   700, train loss 0.001980, train error 0.00,  test loss 4.946905, test error 53.05
# Epoch   800, train loss 0.001628, train error 0.00,  test loss 5.075071, test error 52.97
# Epoch   900, train loss 0.001376, train error 0.00,  test loss 5.185322, test error 52.97
# Training model with  90 hidden variables
# Epoch     0, train loss 2.020873, train error 73.50,  test loss 1.977609, test error 74.15
# Epoch   100, train loss 0.161199, train error 2.05,  test loss 2.203621, test error 52.42
# Epoch   200, train loss 0.014757, train error 0.00,  test loss 3.260767, test error 51.62
# Epoch   300, train loss 0.006375, train error 0.00,  test loss 3.685285, test error 51.85
# Epoch   400, train loss 0.003900, train error 0.00,  test loss 3.958313, test error 51.80
# Epoch   500, train loss 0.002743, train error 0.00,  test loss 4.151288, test error 52.08
# Epoch   600, train loss 0.002085, train error 0.00,  test loss 4.301708, test error 52.15
# Epoch   700, train loss 0.001668, train error 0.00,  test loss 4.424504, test error 52.25
# Epoch   800, train loss 0.001379, train error 0.00,  test loss 4.528306, test error 52.22
# Epoch   900, train loss 0.001170, train error 0.00,  test loss 4.618177, test error 52.17
# Training model with 100 hidden variables
# Epoch     0, train loss 2.022280, train error 75.43,  test loss 1.942916, test error 75.05
# Epoch   100, train loss 0.098734, train error 0.20,  test loss 2.255968, test error 51.30
# Epoch   200, train loss 0.012704, train error 0.00,  test loss 3.162215, test error 52.22
# Epoch   300, train loss 0.005879, train error 0.00,  test loss 3.529762, test error 52.15
# Epoch   400, train loss 0.003656, train error 0.00,  test loss 3.763669, test error 52.17
# Epoch   500, train loss 0.002592, train error 0.00,  test loss 3.934599, test error 52.08
# Epoch   600, train loss 0.001983, train error 0.00,  test loss 4.069704, test error 52.05
# Epoch   700, train loss 0.001591, train error 0.00,  test loss 4.180778, test error 51.95
# Epoch   800, train loss 0.001322, train error 0.00,  test loss 4.274583, test error 51.90
# Epoch   900, train loss 0.001125, train error 0.00,  test loss 4.355191, test error 51.95
# Training model with 120 hidden variables
# Epoch     0, train loss 1.999752, train error 74.47,  test loss 1.930405, test error 75.68
# Epoch   100, train loss 0.048853, train error 0.00,  test loss 2.298852, test error 51.80
# Epoch   200, train loss 0.009423, train error 0.00,  test loss 2.916237, test error 51.58
# Epoch   300, train loss 0.004675, train error 0.00,  test loss 3.196113, test error 51.62
# Epoch   400, train loss 0.002993, train error 0.00,  test loss 3.378431, test error 51.65
# Epoch   500, train loss 0.002159, train error 0.00,  test loss 3.513169, test error 51.70
# Epoch   600, train loss 0.001669, train error 0.00,  test loss 3.618867, test error 51.70
# Epoch   700, train loss 0.001351, train error 0.00,  test loss 3.705788, test error 51.75
# Epoch   800, train loss 0.001128, train error 0.00,  test loss 3.780520, test error 51.70
# Epoch   900, train loss 0.000964, train error 0.00,  test loss 3.845030, test error 51.67
# Training model with 140 hidden variables
# Epoch     0, train loss 1.971459, train error 73.03,  test loss 1.909534, test error 73.30
# Epoch   100, train loss 0.036773, train error 0.00,  test loss 2.115669, test error 48.17
# Epoch   200, train loss 0.008069, train error 0.00,  test loss 2.581890, test error 48.15
# Epoch   300, train loss 0.004113, train error 0.00,  test loss 2.806040, test error 48.25
# Epoch   400, train loss 0.002672, train error 0.00,  test loss 2.951992, test error 48.50
# Epoch   500, train loss 0.001946, train error 0.00,  test loss 3.060493, test error 48.53
# Epoch   600, train loss 0.001512, train error 0.00,  test loss 3.147347, test error 48.60
# Epoch   700, train loss 0.001228, train error 0.00,  test loss 3.219400, test error 48.67
# Epoch   800, train loss 0.001028, train error 0.00,  test loss 3.281633, test error 48.62
# Epoch   900, train loss 0.000881, train error 0.00,  test loss 3.335227, test error 48.62
# Training model with 160 hidden variables
# Epoch     0, train loss 1.933856, train error 72.12,  test loss 1.849509, test error 71.15
# Epoch   100, train loss 0.028931, train error 0.00,  test loss 2.181945, test error 50.00
# Epoch   200, train loss 0.007274, train error 0.00,  test loss 2.617300, test error 50.10
# Epoch   300, train loss 0.003811, train error 0.00,  test loss 2.821786, test error 50.03
# Epoch   400, train loss 0.002504, train error 0.00,  test loss 2.959514, test error 49.95
# Epoch   500, train loss 0.001832, train error 0.00,  test loss 3.063800, test error 49.92
# Epoch   600, train loss 0.001430, train error 0.00,  test loss 3.146181, test error 49.88
# Epoch   700, train loss 0.001165, train error 0.00,  test loss 3.214540, test error 49.90
# Epoch   800, train loss 0.000977, train error 0.00,  test loss 3.273241, test error 49.90
# Epoch   900, train loss 0.000839, train error 0.00,  test loss 3.324063, test error 49.92
# Training model with 180 hidden variables
# Epoch     0, train loss 1.957493, train error 71.22,  test loss 1.886195, test error 72.43
# Epoch   100, train loss 0.024253, train error 0.00,  test loss 2.106824, test error 48.85
# Epoch   200, train loss 0.006508, train error 0.00,  test loss 2.461268, test error 48.50
# Epoch   300, train loss 0.003486, train error 0.00,  test loss 2.645572, test error 48.60
# Epoch   400, train loss 0.002312, train error 0.00,  test loss 2.767192, test error 48.55
# Epoch   500, train loss 0.001698, train error 0.00,  test loss 2.859311, test error 48.40
# Epoch   600, train loss 0.001329, train error 0.00,  test loss 2.932843, test error 48.35
# Epoch   700, train loss 0.001084, train error 0.00,  test loss 2.994022, test error 48.53
# Epoch   800, train loss 0.000911, train error 0.00,  test loss 3.046344, test error 48.42
# Epoch   900, train loss 0.000783, train error 0.00,  test loss 3.091774, test error 48.47
# Training model with 200 hidden variables
# Epoch     0, train loss 1.909157, train error 70.43,  test loss 1.852596, test error 71.68
# Epoch   100, train loss 0.021556, train error 0.00,  test loss 2.006268, test error 48.00
# Epoch   200, train loss 0.006113, train error 0.00,  test loss 2.315748, test error 47.50
# Epoch   300, train loss 0.003325, train error 0.00,  test loss 2.473860, test error 47.75
# Epoch   400, train loss 0.002214, train error 0.00,  test loss 2.580237, test error 47.38
# Epoch   500, train loss 0.001634, train error 0.00,  test loss 2.661912, test error 47.45
# Epoch   600, train loss 0.001284, train error 0.00,  test loss 2.726762, test error 47.53
# Epoch   700, train loss 0.001050, train error 0.00,  test loss 2.780673, test error 47.40
# Epoch   800, train loss 0.000884, train error 0.00,  test loss 2.827559, test error 47.42
# Epoch   900, train loss 0.000761, train error 0.00,  test loss 2.867705, test error 47.47
# Training model with 250 hidden variables
# Epoch     0, train loss 1.892911, train error 68.53,  test loss 1.830785, test error 71.30
# Epoch   100, train loss 0.016873, train error 0.00,  test loss 1.897319, test error 47.33
# Epoch   200, train loss 0.005312, train error 0.00,  test loss 2.156192, test error 47.70
# Epoch   300, train loss 0.002960, train error 0.00,  test loss 2.289516, test error 47.58
# Epoch   400, train loss 0.001997, train error 0.00,  test loss 2.379773, test error 47.60
# Epoch   500, train loss 0.001485, train error 0.00,  test loss 2.447890, test error 47.65
# Epoch   600, train loss 0.001172, train error 0.00,  test loss 2.503011, test error 47.65
# Epoch   700, train loss 0.000962, train error 0.00,  test loss 2.550248, test error 47.62
# Epoch   800, train loss 0.000812, train error 0.00,  test loss 2.590334, test error 47.62
# Epoch   900, train loss 0.000701, train error 0.00,  test loss 2.625587, test error 47.62
# Training model with 300 hidden variables
# Epoch     0, train loss 1.864901, train error 67.68,  test loss 1.809224, test error 70.62
# Epoch   100, train loss 0.014496, train error 0.00,  test loss 1.907727, test error 47.70
# Epoch   200, train loss 0.004854, train error 0.00,  test loss 2.135067, test error 47.92
# Epoch   300, train loss 0.002750, train error 0.00,  test loss 2.256509, test error 47.80
# Epoch   400, train loss 0.001875, train error 0.00,  test loss 2.339921, test error 47.80
# Epoch   500, train loss 0.001403, train error 0.00,  test loss 2.403264, test error 47.88
# Epoch   600, train loss 0.001112, train error 0.00,  test loss 2.455030, test error 47.85
# Epoch   700, train loss 0.000916, train error 0.00,  test loss 2.498370, test error 47.80
# Epoch   800, train loss 0.000775, train error 0.00,  test loss 2.535744, test error 47.85
# Epoch   900, train loss 0.000670, train error 0.00,  test loss 2.568648, test error 47.83
# Training model with 400 hidden variables
# Epoch     0, train loss 1.808219, train error 64.25,  test loss 1.751615, test error 68.12
# Epoch   100, train loss 0.011655, train error 0.00,  test loss 1.766709, test error 46.20
# Epoch   200, train loss 0.004164, train error 0.00,  test loss 1.941773, test error 46.00
# Epoch   300, train loss 0.002413, train error 0.00,  test loss 2.039841, test error 45.92
# Epoch   400, train loss 0.001662, train error 0.00,  test loss 2.108077, test error 45.80
# Epoch   500, train loss 0.001253, train error 0.00,  test loss 2.160247, test error 45.60
# Epoch   600, train loss 0.000998, train error 0.00,  test loss 2.202880, test error 45.60
# Epoch   700, train loss 0.000825, train error 0.00,  test loss 2.238644, test error 45.55
# Epoch   800, train loss 0.000700, train error 0.00,  test loss 2.269524, test error 45.58
# Epoch   900, train loss 0.000606, train error 0.00,  test loss 2.296766, test error 45.47

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
